# %% [markdown]
# # Mario PPO RL Project
#
# I'll start by saying this was my very first reinforcement learning project I've even attempted. I didn't implement PPO myself from scratch, but I learned a whole lot about what goes into such projects - preprocessing, understanding the environment (an NES emulator in this case), and a lifetime of waiting on my computer!
#
# I watched about a dozen different YouTube videos on AIs that play various games and found the whole concept incredibly intriguing watching how so many algorithms were used. I was eager to learn the differences and to know when one algorithm might be considered a better choice than another. I love tackling challenges that would bring me to new heights in my programming knowledge, so Mario came to my mind as the perfect fit for my new expedition into machine learning.
#
# ### Fun Facts
#
# 1. The whole NES system runs on 2 Kb of RAM and a 1.79 MHz processor! The game screen is 240 wide by 256 pixels tall.
# 2. Due to how early power systems were developed, the North American (NTSC) version of the game runs at 60 fps, and there are two European (PAL) versions - one version is optimized for PAL and the other is not. The unoptimized PAL version runs slower and has slower music, while the optimized version keeps pace with the NTSC version, but occasionally has to skip a frame to do so. This leads to frame-perfect or pixel-perfect tricks being slightly different.
# 3. The NES has 5 channels for sound - 3 were usable for the game's music and audio effects. This is why some of the music stopped if you collected a coin or powerup. This also forced the composers of the era to get creative with the limited number of parts their song could have.
# 4. Licking your old NES cartridges to get them to work is just a placebo effect and you are actually making the problem worse by doing so!
# 5. The average person has a reaction time of about 273ms (or 16 frames in Mario terms) and can mash a controller button 6.69 times every second (or once every 9 frames). My initial AI was not limited by these factor.

# %% [markdown]
# ## Starting the Game
#
# ### Installing the dependencies
#
# There were several things for me to install for this project. `gym`, `gym_super_mario_bros`, and `nes_py` were necessary to get the game running. The game itself is the NTSC version running on an emulator. `nes_py` makes hacking the ram and cheating with the game quite easy! This is handy if I want to make any sort of save states to revert to.
#
# I am using a custom `PyTorch` installation which will let me use my GPU (a little GeForce GTX 1050 Ti) via CUDA and `stable-baselines3` for the actual PPO model. I didn't do any multiprocessing in this project, which would be a next step for me to learn to drastically increase my performance gains.

# %%
# Install the environment
# !pip install gym==0.21.0 gym_super_mario_bros==7.3.0 nes_py --no-input

# This line must be run before the installation of stable-baselines3 to force
# PyTorch to use the GPU via CUDA.
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu117 --no-input

# Stable-baselines3 gives us access to many RL models.
# !pip install stable-baselines3[extra] --no-input
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gym==0.21.0 in c:\users\blake\appdata\roaming\python\python39\site-packages (0.21.0)
# Requirement already satisfied: gym_super_mario_bros==7.3.0 in c:\users\blake\appdata\roaming\python\python39\site-packages (7.3.0)
# Requirement already satisfied: nes_py in c:\users\blake\appdata\roaming\python\python39\site-packages (8.2.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from gym==0.21.0) (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\programdata\anaconda3\lib\site-packages (from gym==0.21.0) (1.21.5)
# Requirement already satisfied: pyglet<=1.5.21,>=1.4.0 in c:\users\blake\appdata\roaming\python\python39\site-packages (from nes_py) (1.5.21)
# Requirement already satisfied: tqdm>=4.48.2 in c:\programdata\anaconda3\lib\site-packages (from nes_py) (4.64.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.48.2->nes_py) (0.4.5)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu117
# Requirement already satisfied: torch in c:\users\blake\appdata\roaming\python\python39\site-packages (1.13.1+cu117)
# Requirement already satisfied: torchvision in c:\users\blake\appdata\roaming\python\python39\site-packages (0.14.1+cu117)
# Requirement already satisfied: torchaudio in c:\users\blake\appdata\roaming\python\python39\site-packages (0.13.1+cu117)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from torch) (4.3.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from torchvision) (9.2.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (3.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: stable-baselines3[extra] in c:\users\blake\appdata\roaming\python\python39\site-packages (1.6.2)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: importlib-metadata~=4.13 in c:\users\blake\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (4.13.0)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.5.2)
# Requirement already satisfied: gym==0.21 in c:\users\blake\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.21.5)
# Requirement already satisfied: torch>=1.11 in c:\users\blake\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (1.13.1+cu117)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in c:\users\blake\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: ale-py==0.7.4 in c:\users\blake\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (0.7.4)
# Requirement already satisfied: opencv-python in c:\users\blake\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (4.7.0.68)
# Requirement already satisfied: rich in c:\users\blake\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (13.0.0)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\blake\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (2.11.0)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (9.2.0)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.64.1)
# Requirement already satisfied: importlib-resources in c:\users\blake\appdata\roaming\python\python39\site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.10.2)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (8.0.4)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.28.1)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\blake\appdata\roaming\python\python39\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (3.8.0)
# Requirement already satisfied: protobuf<4,>=3.9.2 in c:\users\blake\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.19.6)
# Requirement already satisfied: absl-py>=0.4 in c:\users\blake\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\blake\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\blake\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\blake\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.15.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (63.4.1)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\blake\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.51.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\blake\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (4.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2022.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\programdata\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.11.2)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\blake\appdata\roaming\python\python39\site-packages (from rich->stable-baselines3[extra]) (0.9.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\blake\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\blake\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\blake\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2022.9.14)
# Requirement already satisfied: libtorrent in c:\users\blake\appdata\roaming\python\python39\site-packages (from AutoROM.accept-rom-license->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.0.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\blake\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)

# %% [markdown]
# ### Understanding the Game
#
# The NES controller has a total of 8 buttons - `up`, `down`, `left`, `right`, `A`, `B`, `start`, and `select`. On the emulator, all of these buttons could be pressed at the same time, even if such configurations are physically impossible such as `up` and `down` simultaneously. This gives a total of 256 possible input combinations per frame.
#
# We need to limit the action space so the agent can learn easier. We don't want the agent pushing start or select for any reason. Invalid combinations could be avoided as well. Lastly, certain combinations don't yield any special results, such as pushing `down` in conjunction with any other button.
#
# The goal is to run to the right as quick as possible, and the environment rewards Mario based on his change in X position. (Rewarding Mario for the actual score on the screen will cause him to mope around collecting all the coins and grinding enemies.) I decided to force the AI to hold `right` and `B` to constantly run right. All it has to decide is when to push the `A` button to jump. I figured this would net the quickest results as there are no parts of the game where you are forced to move left or stop moving.
#
# The environment will only return frames which are rewardable, so the start screen is skipped and 1 player mode is automatically selected. Similarly, death and other animations are also skipped.

# %%
# Import the game and SIMPLIFIED controls
import gym_super_mario_bros
from gym_super_mario_bros.actions import *
SPEEDRUN_MOVEMENT = [['right', 'B'], ['right', 'A', 'B']]

# Import wrappers
from gym import Wrapper
from nes_py.wrappers import JoypadSpace
from gym.wrappers import GrayScaleObservation, RecordEpisodeStatistics, ResizeObservation
from stable_baselines3.common.vec_env import VecFrameStack, SubprocVecEnv

# Import the RL model
from stable_baselines3 import PPO

# Import utilities for image viewing, file I/O, RNG, etc.
from stable_baselines3.common.callbacks import BaseCallback
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Tetris-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Tetris-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Adventure-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Adventure-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/AirRaid-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/AirRaid-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Alien-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Alien-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Amidar-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Amidar-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Assault-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Assault-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Asterix-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Asterix-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Asteroids-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Asteroids-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Atlantis-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Atlantis-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Atlantis2-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Atlantis2-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Backgammon-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Backgammon-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/BankHeist-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/BankHeist-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/BasicMath-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/BasicMath-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/BattleZone-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/BattleZone-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/BeamRider-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/BeamRider-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Berzerk-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Berzerk-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Blackjack-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Blackjack-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Bowling-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Bowling-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Boxing-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Boxing-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Breakout-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Breakout-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Carnival-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Carnival-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Casino-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Casino-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Centipede-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Centipede-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/ChopperCommand-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/ChopperCommand-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/CrazyClimber-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/CrazyClimber-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Crossbow-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Crossbow-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Darkchambers-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Darkchambers-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Defender-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Defender-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/DemonAttack-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/DemonAttack-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/DonkeyKong-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/DonkeyKong-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/DoubleDunk-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/DoubleDunk-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Earthworld-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Earthworld-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/ElevatorAction-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/ElevatorAction-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Enduro-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Enduro-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Entombed-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Entombed-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Et-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Et-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/FishingDerby-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/FishingDerby-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/FlagCapture-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/FlagCapture-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Freeway-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Freeway-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Frogger-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Frogger-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Frostbite-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Frostbite-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Galaxian-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Galaxian-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Gopher-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Gopher-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Gravitar-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Gravitar-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Hangman-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Hangman-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/HauntedHouse-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/HauntedHouse-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Hero-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Hero-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/HumanCannonball-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/HumanCannonball-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/IceHockey-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/IceHockey-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Jamesbond-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Jamesbond-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/JourneyEscape-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/JourneyEscape-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Kaboom-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Kaboom-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Kangaroo-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Kangaroo-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/KeystoneKapers-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/KeystoneKapers-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/KingKong-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/KingKong-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Klax-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Klax-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Koolaid-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Koolaid-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Krull-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Krull-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/KungFuMaster-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/KungFuMaster-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/LaserGates-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/LaserGates-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/LostLuggage-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/LostLuggage-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/MarioBros-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/MarioBros-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/MiniatureGolf-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/MiniatureGolf-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/MontezumaRevenge-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/MontezumaRevenge-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/MrDo-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/MrDo-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/MsPacman-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/MsPacman-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/NameThisGame-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/NameThisGame-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Othello-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Othello-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Pacman-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Pacman-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Phoenix-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Phoenix-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Pitfall-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Pitfall-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Pitfall2-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Pitfall2-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Pong-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Pong-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Pooyan-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Pooyan-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/PrivateEye-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/PrivateEye-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Qbert-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Qbert-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Riverraid-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Riverraid-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/RoadRunner-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/RoadRunner-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Robotank-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Robotank-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Seaquest-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Seaquest-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/SirLancelot-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/SirLancelot-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Skiing-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Skiing-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Solaris-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Solaris-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/SpaceInvaders-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/SpaceInvaders-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/SpaceWar-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/SpaceWar-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/StarGunner-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/StarGunner-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Superman-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Superman-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Surround-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Surround-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Tennis-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Tennis-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/TicTacToe3D-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/TicTacToe3D-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/TimePilot-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/TimePilot-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Trondead-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Trondead-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Turmoil-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Turmoil-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Tutankham-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Tutankham-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/UpNDown-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/UpNDown-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Venture-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Venture-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/VideoCheckers-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/VideoCheckers-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Videochess-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Videochess-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Videocube-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Videocube-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/VideoPinball-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/VideoPinball-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/WizardOfWor-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/WizardOfWor-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/WordZapper-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/WordZapper-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/YarsRevenge-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/YarsRevenge-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Zaxxon-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ALE/Zaxxon-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Adventure-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AdventureDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AdventureNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Adventure-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AdventureDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AdventureNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Adventure-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Adventure-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Adventure-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Adventure-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Adventure-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Adventure-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AirRaid-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AirRaidDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AirRaidNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AirRaid-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AirRaidDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AirRaidNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AirRaid-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AirRaid-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AirRaid-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AirRaid-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AirRaid-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment AirRaid-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Alien-v0
#   logger.warn("Overriding environment {}".format(id))
# ...
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Tutankham-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Tutankham-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Tutankham-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Tutankham-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment UpNDown-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment UpNDownDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment UpNDownNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment UpNDown-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment UpNDownDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment UpNDownNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Venture-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VentureDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VentureNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Venture-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VentureDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VentureNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Venture-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Venture-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Venture-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Venture-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Venture-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Venture-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VideoPinballDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VideoPinballNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VideoPinballDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VideoPinballNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment WizardOfWorDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment WizardOfWorNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment WizardOfWorDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment WizardOfWorNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment YarsRevengeDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment YarsRevengeNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment YarsRevengeDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment YarsRevengeNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ZaxxonDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ZaxxonNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ZaxxonDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment ZaxxonNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))

# %% [markdown]
# ## Testing the Environment
#
# The specific environment I used was one which selected a random stage on each reset. I did this to help the AI generalize as well as to reduce overfitting on the first level. Plus, it would be very slow if Mario had to go through all 7 of the other worlds before getting to world 8 which the AI needs to learn.
#
# This had me thinking of implementing a similar idea for a single level as well - what if we could rewind a second or two and the AI could retry just the part where it died instead of having to run through the first half of the level? There were some pitfalls in this logic about perhaps getting stuck in death loops, so I did not implement this until later to measure the improvements that could be made.
#
# The environment also turns everything into rectangles to reduce the complexity of the information for the agent. The code below tests the game for a few seconds to ensure that it is working properly.

# %%
# Create and wrap the environment
env = gym_super_mario_bros.make('SuperMarioBros-v3')
env = JoypadSpace(env, SIMPLE_MOVEMENT)
state = env.reset()
env.render()

# Test the game with random actions
try:
    for step in range(10 ** 3):
        # Pick a random action
        action = env.action_space.sample()
        state, reward, done, info = env.step(action)
        
        if done:
            env.reset()
        env.render()
except KeyboardInterrupt:
    pass
finally:
    env.close()
# Out:
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# C:\Users\Blake\AppData\Roaming\Python\Python39\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256

# %% [markdown]
# ## Preprocessing
#
# The design choices I made here were intended to help speed up the rate that the AI learns and to model human reactions a little better. The base environment that I used was a rectangular downsample of the whole game - sprites are reduced to only their hitboxes. I also grayscale the image which could possibly cut out on important information (such as not being able to distinguish red lava and a gray floor) but will overall speed up the learning process.
#
# Original | Downsampled | Grayscaled
# - | - | -
# ![mario original](smb_original.png) | ![mario downsampled](smb_rectangle.png) | ![mario grayscale](smb_grayscale.png)
#
# ### Deadlock
#
# I decided if Mario gets stuck and does not progress for 3 seconds then he should be killed off without having to wait minutes for the timer to run out in order to restart.

# %%
class DeadlockEnv(Wrapper):
    
    def __init__(self, env, threshold):
        super().__init__(env)
        self.threshold = threshold
    
    def reset(self, **kwargs):
        self.max_x_pos = 0
        self.count = 0
        return self.env.reset(**kwargs)
    
    def step(self, action):
        state, reward, done, info = self.env.step(action)
        x_pos = info['x_pos']
        if x_pos <= self.max_x_pos:
            self.count += 1
        else:
            self.count = 0
            self.max_x_pos = x_pos
        
        if self.count >= self.threshold:
            reward -= 15
            done = True
        
        return state, reward, done, info

# %% [markdown]
# ### Skipping Frames
#
# The AI can change inputs every 5 frames to model human limitations. This also makes it easier to do things like jump over pipes, where the a button needs to be held for several frames. The reward for the frames is summated.

# %%
class SkipFrame(Wrapper):
    
    def __init__(self, env, skip):
        super().__init__(env)
        self._skip = skip
    
    def step(self, action):
        total_reward = 0
        for i in range(self._skip):
            state, reward, done, info = self.env.step(action)
            total_reward += reward
            if done:
                break
        return state, total_reward, done, info

# %% [markdown]
# ### Other Wrappers
#
# I also grayscale the image and reduced the size by half to reduce the information passed to the AI. (If you try to display the image using Matplotlib, it messes with the colors on a grayscale image when rendering the output for visibility.)
#
# The environment is put into a subprocess environment for the PPO algorithm to play multiple games at once, utilizing the GPU.
#
# Then, a total of 4 frames are stacked on each other to give the AI a sense of motion and acceleration.
#
# Now we just create the actual environment and wrap everything up.

# %%
def create_env(ranks, seed = 0):
    
    def helper(rank):
        # 1. Create the base environment
        env = gym_super_mario_bros.make('SuperMarioBros-v3')
        env.seed(seed + rank)

        # 2. Simplify the controls
        env = JoypadSpace(env, COMPLEX_MOVEMENT)

        # 3. If Mario is not making progress after 180 frames (3 seconds), end it
        env = DeadlockEnv(env, 60 * 3)

        # 4. Skip frames so the agent can only change button presses every 5 frames
        # env = SkipFrame(env, 5)

        # 5. Grayscale - This cuts down on info for the agent to learn
        env = GrayScaleObservation(env, keep_dim=True)
        
        # 6. Resize the image to 50%
        env = ResizeObservation(env, (120, 128))
        
        # 7. Record stats about the env for tensorboard
        env = RecordEpisodeStatistics(env)
        
        return env

    # 8. Wrap inside Dummy Vector Env
    env = SubprocVecEnv([(lambda: helper(i)) for i in range(ranks)])

    # 9. Stack the frames
    env = VecFrameStack(env, 4, channels_order='last')
    
    return env

# %% [markdown]
# ## Logging and Training
#
# Initially I decided to train the model for a total of 1 million timesteps and benchmark the progress every 10,000 steps. I used a learning rate of 1e-6 and chose to update the model every 512 steps.

# %%
# Helper class will save our model every n steps
class TrainAndLoggingCallback(BaseCallback):
    
    def __init__(self, save_freq, save_path, verbose = 1):
        super().__init__(verbose)
        self.save_freq = save_freq
        self.save_path = save_path
    
    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
    
    def _on_step(self):
        if self.n_calls % self.save_freq == 0:
            model_path = os.path.join(self.save_path,
                                      f'best_model_{self.n_calls // 1000}k')
            self.model.save(model_path)
        return True

# %%
# Set up save dirs
CHECKPOINT_DIR = 'E:/train/'
TRAIN_DIR = 'E:/logs/'
MODEL_PATH = 'E:/train/finished_model'
REWARD_LOG = TRAIN_DIR + 'reward_log.csv'

# Set up constants
SAVE_FREQ = 10 ** 5
NUM_SUBPROCESSES = 4

# Set up the model saving callback
callback = TrainAndLoggingCallback(SAVE_FREQ // NUM_SUBPROCESSES,
                                   CHECKPOINT_DIR)
env = create_env(NUM_SUBPROCESSES)

# %%
# Create the model (policy)
model = PPO('CnnPolicy',
            env = env,
            verbose = 1,
            tensorboard_log = TRAIN_DIR,
            learning_rate = 1e-5,
            n_steps = 512)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
try:
    # Train and save model
    model.learn(total_timesteps = 10 ** 6,
                callback = callback)
    model.save(MODEL_PATH)
except KeyboardInterrupt:
    pass
finally:
    # Free memory, close resources
    del model
    del env
    print('Freed memory and closed resources.')
# Out:
# Logging to E:/logs/PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | -34.4    |
# | time/              |          |
# |    fps             | 283      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 302         |
# |    ep_rew_mean          | 9.75        |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 2           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015081482 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.48       |
# |    explained_variance   | 0.000377    |
# |    learning_rate        | 1e-05       |
# |    loss                 | 7.12        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 19.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 437         |
# |    ep_rew_mean          | 75.4        |
# | time/                   |             |
# |    fps                  | 223         |
# |    iterations           | 3           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012658726 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | 0.332       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 25.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00602    |
# |    value_loss           | 49.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 505         |
# |    ep_rew_mean          | 113.09091   |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 4           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013993548 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.4        |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 14.7        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 42.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 610         |
# |    ep_rew_mean          | 206.13333   |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 5           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009305805 |
# |    clip_fraction        | 0.0622      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 17.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00508    |
# |    value_loss           | 67.7        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 608       |
# |    ep_rew_mean          | 234.70589 |
# | time/                   |           |
# |    fps                  | 213       |
# |    iterations           | 6         |
# |    time_elapsed         | 57        |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0158609 |
# |    clip_fraction        | 0.141     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.36     |
# |    explained_variance   | 0.691     |
# |    learning_rate        | 1e-05     |
# |    loss                 | 30.9      |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -0.0102   |
# |    value_loss           | 83.8      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 615         |
# |    ep_rew_mean          | 289.5909    |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 7           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009590997 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.34       |
# |    explained_variance   | 0.722       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 47.4        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00619    |
# |    value_loss           | 121         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 615         |
# |    ep_rew_mean          | 294.91666   |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 8           |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012417962 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 45.2        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00464    |
# |    value_loss           | 121         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 631         |
# |    ep_rew_mean          | 312.62964   |
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 9           |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010202686 |
# |    clip_fraction        | 0.0794      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 46.5        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00399    |
# |    value_loss           | 92          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 629         |
# |    ep_rew_mean          | 333.41934   |
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 10          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010311637 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 52.1        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00718    |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 615         |
# |    ep_rew_mean          | 336.82352   |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 11          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010392243 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 28.1        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00772    |
# |    value_loss           | 105         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 610         |
# |    ep_rew_mean          | 349.6316    |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 12          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013475403 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 129         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00795    |
# |    value_loss           | 179         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 599         |
# |    ep_rew_mean          | 362.90475   |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 13          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.012242183 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 64.3        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00536    |
# |    value_loss           | 211         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 599         |
# |    ep_rew_mean          | 375.85107   |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 14          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009095558 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 66.3        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00529    |
# |    value_loss           | 233         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 597         |
# |    ep_rew_mean          | 378.8125    |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 15          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008352915 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 59.4        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00348    |
# |    value_loss           | 224         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 600          |
# |    ep_rew_mean          | 389.1346     |
# | time/                   |              |
# |    fps                  | 208          |
# |    iterations           | 16           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0099492315 |
# |    clip_fraction        | 0.143        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 18.9         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 97.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 598         |
# |    ep_rew_mean          | 398.10715   |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 17          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011130121 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 33.5        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00213    |
# |    value_loss           | 82.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 596         |
# |    ep_rew_mean          | 403.45764   |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 18          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010934402 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.08       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 35.2        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00332    |
# |    value_loss           | 59.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 589         |
# |    ep_rew_mean          | 407.42188   |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 19          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.014227308 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 48          |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00241    |
# |    value_loss           | 106         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 591         |
# |    ep_rew_mean          | 412.1791    |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 20          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008339605 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 54.6        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0015     |
# |    value_loss           | 111         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 592        |
# |    ep_rew_mean          | 417.9014   |
# | time/                   |            |
# |    fps                  | 207        |
# |    iterations           | 21         |
# |    time_elapsed         | 207        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01372692 |
# |    clip_fraction        | 0.141      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.04      |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 23.6       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00401   |
# |    value_loss           | 59.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 588         |
# |    ep_rew_mean          | 422.8       |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 22          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010218539 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 20.2        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0012     |
# |    value_loss           | 53.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 586        |
# |    ep_rew_mean          | 426.98734  |
# | time/                   |            |
# |    fps                  | 207        |
# |    iterations           | 23         |
# |    time_elapsed         | 227        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01002839 |
# |    clip_fraction        | 0.175      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.03      |
# |    explained_variance   | 0.907      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 73.4       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00521   |
# |    value_loss           | 160        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 584         |
# |    ep_rew_mean          | 427.25925   |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 24          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009452672 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 160         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00185     |
# |    value_loss           | 135         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 583         |
# |    ep_rew_mean          | 436.84885   |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 25          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.013322204 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 35.3        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00353    |
# |    value_loss           | 75.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 586        |
# |    ep_rew_mean          | 440.809    |
# | time/                   |            |
# |    fps                  | 206        |
# |    iterations           | 26         |
# |    time_elapsed         | 257        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.01317901 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.84      |
# |    explained_variance   | 0.93       |
# |    learning_rate        | 1e-05      |
# |    loss                 | 408        |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.00659   |
# |    value_loss           | 225        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 586         |
# |    ep_rew_mean          | 447.07526   |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 27          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.006990899 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 38.2        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000569   |
# |    value_loss           | 138         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 586         |
# |    ep_rew_mean          | 448.50525   |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 28          |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.006825015 |
# |    clip_fraction        | 0.0561      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 58.5        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00113    |
# |    value_loss           | 262         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 586         |
# |    ep_rew_mean          | 453.9       |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 29          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.009230632 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 57.6        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00173    |
# |    value_loss           | 145         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 603         |
# |    ep_rew_mean          | 480.58      |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 30          |
# |    time_elapsed         | 297         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.015127425 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 32.1        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00213    |
# |    value_loss           | 196         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 608         |
# |    ep_rew_mean          | 497.37      |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 31          |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.007682711 |
# |    clip_fraction        | 0.0864      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 252         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00283    |
# |    value_loss           | 287         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 590          |
# |    ep_rew_mean          | 506.89       |
# | time/                   |              |
# |    fps                  | 206          |
# |    iterations           | 32           |
# |    time_elapsed         | 317          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0077662603 |
# |    clip_fraction        | 0.0828       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.6         |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 30.5         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00453     |
# |    value_loss           | 80           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 572         |
# |    ep_rew_mean          | 509.83      |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 33          |
# |    time_elapsed         | 327         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.007374663 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 43.3        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00184    |
# |    value_loss           | 208         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 566          |
# |    ep_rew_mean          | 518.91       |
# | time/                   |              |
# |    fps                  | 206          |
# |    iterations           | 34           |
# |    time_elapsed         | 337          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0056786113 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 77           |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000674    |
# |    value_loss           | 247          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 567         |
# |    ep_rew_mean          | 523.54      |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 35          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.005530265 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 142         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.000594   |
# |    value_loss           | 153         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 562         |
# |    ep_rew_mean          | 535.24      |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 36          |
# |    time_elapsed         | 357         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.017844604 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 115         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.000214   |
# |    value_loss           | 187         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 560         |
# |    ep_rew_mean          | 538.54      |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 37          |
# |    time_elapsed         | 367         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.020462222 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 17.1        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.000615   |
# |    value_loss           | 51.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 563        |
# |    ep_rew_mean          | 550.97     |
# | time/                   |            |
# |    fps                  | 206        |
# |    iterations           | 38         |
# |    time_elapsed         | 377        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.01986834 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 26         |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00254   |
# |    value_loss           | 50         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 563         |
# |    ep_rew_mean          | 555.13      |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 39          |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.013745242 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 82.9        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00435    |
# |    value_loss           | 255         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 562          |
# |    ep_rew_mean          | 554.6        |
# | time/                   |              |
# |    fps                  | 205          |
# |    iterations           | 40           |
# |    time_elapsed         | 397          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0108936895 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.64        |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 40           |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.00153      |
# |    value_loss           | 136          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 566         |
# |    ep_rew_mean          | 561.08      |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 41          |
# |    time_elapsed         | 407         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.007549705 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 32.4        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0032     |
# |    value_loss           | 60.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 562         |
# |    ep_rew_mean          | 562.44      |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 42          |
# |    time_elapsed         | 417         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008655293 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 113         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00354    |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 556         |
# |    ep_rew_mean          | 562.7       |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 43          |
# |    time_elapsed         | 427         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.010551851 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 12.2        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00147     |
# |    value_loss           | 57.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 557         |
# |    ep_rew_mean          | 566.54      |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 44          |
# |    time_elapsed         | 437         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011262059 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 12.8        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00233    |
# |    value_loss           | 46.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 558         |
# |    ep_rew_mean          | 572.28      |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 45          |
# |    time_elapsed         | 447         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018514048 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 44.4        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.000825   |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 557         |
# |    ep_rew_mean          | 573.9       |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 46          |
# |    time_elapsed         | 457         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.010767363 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 16.6        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.000133    |
# |    value_loss           | 48.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 555          |
# |    ep_rew_mean          | 577.39       |
# | time/                   |              |
# |    fps                  | 205          |
# |    iterations           | 47           |
# |    time_elapsed         | 467          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0067659924 |
# |    clip_fraction        | 0.142        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.59        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 18.9         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00302     |
# |    value_loss           | 75.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 553         |
# |    ep_rew_mean          | 580.01      |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 48          |
# |    time_elapsed         | 477         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.007358323 |
# |    clip_fraction        | 0.0653      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 132         |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00195    |
# |    value_loss           | 206         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 550         |
# |    ep_rew_mean          | 584.29      |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 49          |
# |    time_elapsed         | 489         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.013046709 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 30.9        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00032    |
# |    value_loss           | 103         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 551        |
# |    ep_rew_mean          | 587.22     |
# | time/                   |            |
# |    fps                  | 205        |
# |    iterations           | 50         |
# |    time_elapsed         | 499        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.00933959 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.61      |
# |    explained_variance   | 0.989      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 27.9       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.00192   |
# |    value_loss           | 44.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 550         |
# |    ep_rew_mean          | 591.45      |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 51          |
# |    time_elapsed         | 508         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.017585145 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 18.4        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00417    |
# |    value_loss           | 36.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 547         |
# |    ep_rew_mean          | 587.09      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 52          |
# |    time_elapsed         | 519         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.009853799 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 14          |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00341    |
# |    value_loss           | 34.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 545         |
# |    ep_rew_mean          | 589.75      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 53          |
# |    time_elapsed         | 529         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.013768259 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 162         |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00622    |
# |    value_loss           | 189         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 540         |
# |    ep_rew_mean          | 586.72      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 54          |
# |    time_elapsed         | 539         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.010432964 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 16          |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00169    |
# |    value_loss           | 53.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 538         |
# |    ep_rew_mean          | 586.0       |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 55          |
# |    time_elapsed         | 549         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.024985477 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 45.3        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.000948   |
# |    value_loss           | 91          |
# -----------------------------------------
# ----------------------------------------
# ...
# |    value_loss           | 22.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 649          |
# |    ep_rew_mean          | 727.11       |
# | time/                   |              |
# |    fps                  | 204          |
# |    iterations           | 472          |
# |    time_elapsed         | 4732         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0155721065 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.831       |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 62.7         |
# |    n_updates            | 4710         |
# |    policy_gradient_loss | -0.0059      |
# |    value_loss           | 56.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 653         |
# |    ep_rew_mean          | 728.11      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 473         |
# |    time_elapsed         | 4742        |
# |    total_timesteps      | 968704      |
# | train/                  |             |
# |    approx_kl            | 0.006708785 |
# |    clip_fraction        | 0.0842      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.808      |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 23.7        |
# |    n_updates            | 4720        |
# |    policy_gradient_loss | -0.00822    |
# |    value_loss           | 108         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 651         |
# |    ep_rew_mean          | 723.15      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 474         |
# |    time_elapsed         | 4752        |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.008109858 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 62.7        |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | -0.00844    |
# |    value_loss           | 106         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 653         |
# |    ep_rew_mean          | 721.5       |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 475         |
# |    time_elapsed         | 4762        |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.011327892 |
# |    clip_fraction        | 0.0976      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.803      |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 12.4        |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | -0.00736    |
# |    value_loss           | 53.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 654         |
# |    ep_rew_mean          | 721.58      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 476         |
# |    time_elapsed         | 4771        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.020183804 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 8.51        |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | -0.0068     |
# |    value_loss           | 21          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 654         |
# |    ep_rew_mean          | 722.89      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 477         |
# |    time_elapsed         | 4781        |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.012699418 |
# |    clip_fraction        | 0.0878      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.676      |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 86.8        |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | -0.00764    |
# |    value_loss           | 154         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 654         |
# |    ep_rew_mean          | 714.2       |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 478         |
# |    time_elapsed         | 4791        |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.008439445 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 47.5        |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | 0.00436     |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 653         |
# |    ep_rew_mean          | 709.77      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 479         |
# |    time_elapsed         | 4801        |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.020980725 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 111         |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.00627    |
# |    value_loss           | 169         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 652         |
# |    ep_rew_mean          | 704.11      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 480         |
# |    time_elapsed         | 4811        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.011329982 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.658      |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 85.1        |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 107         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 653        |
# |    ep_rew_mean          | 704.18     |
# | time/                   |            |
# |    fps                  | 204        |
# |    iterations           | 481        |
# |    time_elapsed         | 4821       |
# |    total_timesteps      | 985088     |
# | train/                  |            |
# |    approx_kl            | 0.00989325 |
# |    clip_fraction        | 0.0854     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.727     |
# |    explained_variance   | 0.969      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 16         |
# |    n_updates            | 4800       |
# |    policy_gradient_loss | -0.00339   |
# |    value_loss           | 63.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 652         |
# |    ep_rew_mean          | 698.45      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 482         |
# |    time_elapsed         | 4831        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.006273473 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.717      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 110         |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.00101    |
# |    value_loss           | 116         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 653         |
# |    ep_rew_mean          | 702.25      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 483         |
# |    time_elapsed         | 4841        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.012493011 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 53.7        |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.00486    |
# |    value_loss           | 206         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 650         |
# |    ep_rew_mean          | 701.09      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 484         |
# |    time_elapsed         | 4851        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.041238353 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.934      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 28.3        |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.00851    |
# |    value_loss           | 52.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 656         |
# |    ep_rew_mean          | 708.51      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 485         |
# |    time_elapsed         | 4860        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.031434815 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.748      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 27          |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.00861    |
# |    value_loss           | 52.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 654         |
# |    ep_rew_mean          | 711.28      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 486         |
# |    time_elapsed         | 4870        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.011510061 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.931      |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 17          |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | -0.00999    |
# |    value_loss           | 45.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 642         |
# |    ep_rew_mean          | 694.68      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 487         |
# |    time_elapsed         | 4880        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.007713286 |
# |    clip_fraction        | 0.0703      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.593      |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 73.5        |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | 0.00361     |
# |    value_loss           | 203         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 640         |
# |    ep_rew_mean          | 688.73      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 488         |
# |    time_elapsed         | 4890        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.012445931 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 28          |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.00593    |
# |    value_loss           | 81.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 632         |
# |    ep_rew_mean          | 690.75      |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 489         |
# |    time_elapsed         | 4900        |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.010795587 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 19.9        |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | -0.00631    |
# |    value_loss           | 52.9        |
# -----------------------------------------
# Freed memory and closed resources.

# %% [markdown]
# ## Testing the Model

# %%
# Load the model
model = PPO.load('E:/Train/finished_model.zip',
                 #env = create_env(4),
                 reset_num_timesteps = False,
                 tensorboard_log=TRAIN_DIR)

# %%
env = create_env(1)
state = env.reset()
try:
    while True:
        action, _ = model.predict(state)
        state, reward, done, info = env.step(action)
        env.render()
except KeyboardInterrupt:
    pass
finally:
    env.close()

# %% [markdown]
# ## The Results

# %% [markdown]
# # Future improvements
#
# Some basics are lowering the learning rate and giving the model more time to run. Other algorithms and model architectures besides PPO could also be tried. If the model is running into pixel perfect boundaries, the size of the screen could be kept the same. If some color palletes clash on the grayscale image, then the full RGB bands could be used as well. However, these will slow down training.
#
# One issue the AI faces is having to spend a lot of time playing through the first part of a level in order to get to a new part to learn. This is especially troublesome if we would all the levels to be played. The gym-super-mario-bros environment allows Mario to start on a random world which can deal with this. Another remedy is to save the current state every second (up to 5 saved states) and when Mario dies, revert back to the state from 5 seconds ago to retry the new part again.
